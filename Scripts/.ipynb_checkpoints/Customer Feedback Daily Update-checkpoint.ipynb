# %%
import pandas as pd
import numpy as np
import snowflake.connector
from collections import defaultdict
import json
import re
import requests
import sys
import random
import requests
import tabulate
from datetime import datetime
import schedule
import time

# %%
#login to snowflake db
con = snowflake.connector.connect(user='vishal.kumar@scale.com',
                                 account='pxa65918',
                                 authenticator='externalbrowser',
                                 warehouse='COMPUTE_WH',
                                 database='SCALE_CRAWLER',
                                 role='GENERAL_RO')

cs = con.cursor()
# Out:
# Initiating login request with your identity provider. A browser window should have opened for you to complete the login. If you can't see it, check existing browser windows, or your OS settings. Press CTRL+C to abort and try again...

# %%
#Get work logs
sql = f'''
with cf as (
  select
    DOMAIN,
    STATUS,
    CATALOG_ID,
    _ID,
    CAST(CLAIMED_AT as Date) CLAIMED_AT,
    CAST(COMPLETED_AT as Date) COMPLETED_AT,
    AUDIT_LEVEL,
    CAST(CREATED_AT as Date) CREATED_AT,
    CUSTOMER_FEEDBACK_DATE_SENT,
    USER_EMAIL,
 --   FEEDBACK as fed_json,
    RESULT as res_json
  from
    PUBLIC.SPOTTERAUDITS
  WHERE
    AUDIT_TYPE = 'CustomerFeedback'
    AND STATUS != 'Canceled'
    AND COMPLETED_AT > '2022-10-06'
)
select
  cf.STATUS,
  cf._ID,
  cf.CATALOG_ID,
  cf.AUDIT_LEVEL,
  cf.CREATED_AT,
  cf.CLAIMED_AT,
  cf.COMPLETED_AT,
  cf.CUSTOMER_FEEDBACK_DATE_SENT,
  cf.USER_EMAIL,
  a.key PRODUCT_ID,
  b.key ATTRIBUTE,
  c.value AUDIT_RESULT
--  d.key USEREMAIL,
--  e.value FEMAIL 
  --  c.key AUDIT,
  --  c.value RES
FROM
  cf,
  lateral flatten (input => res_json) a,
  lateral flatten (input => a.value, outer => true) b,
  lateral flatten (input => b.value, outer => true) c
--  lateral flatten (input => fed_json) d,
--  lateral flatten (input => d.value, outer => true) e
'''
cs.execute(sql)
worklogdf = cs.fetch_pandas_all()

# %%
worklogdf['LEVEL'] = np.where(worklogdf['USER_EMAIL'].str.contains("contractors"), 'QA', np.where(worklogdf['USER_EMAIL'].str.contains("telework"), 'TW', 'ScaleHQ'))

# %%
worklogdf
# Out:
#                      STATUS                       _ID CATALOG_ID AUDIT_LEVEL  \
# 0                  Accepted  633b89de302b8971b5145b8d       None    Reviewer
# 1                  Accepted  633b89de302b8971b5145b8d       None    Reviewer
# 2                  Accepted  633b89de302b8971b5145b8d       None    Reviewer
# 3                  Accepted  633b89de302b8971b5145b8d       None    Reviewer
# 4                  Accepted  633b89de302b8971b5145b8d       None    Reviewer
# ...                     ...                       ...        ...         ...
# 287927  Submitted To Review  633b900a302b8907bb15c077       None   Attempter
# 287928  Submitted To Review  633b900a302b8907bb15c077       None   Attempter
# 287929  Submitted To Review  633b900a302b8907bb15c077       None   Attempter
# 287930  Submitted To Review  633b900a302b8907bb15c077       None   Attempter
# 287931  Submitted To Review  633b900a302b8907bb15c077       None   Attempter
#
#         CREATED_AT  CLAIMED_AT COMPLETED_AT CUSTOMER_FEEDBACK_DATE_SENT  \
# 0       2022-10-04  2022-10-07   2022-10-07                  2022-10-02
# 1       2022-10-04  2022-10-07   2022-10-07                  2022-10-02
# 2       2022-10-04  2022-10-07   2022-10-07                  2022-10-02
# 3       2022-10-04  2022-10-07   2022-10-07                  2022-10-02
# 4       2022-10-04  2022-10-07   2022-10-07                  2022-10-02
# ...            ...         ...          ...                         ...
# 287927  2022-10-04  2022-10-04   2022-10-05                  2022-09-22
# 287928  2022-10-04  2022-10-04   2022-10-05                  2022-09-22
# 287929  2022-10-04  2022-10-04   2022-10-05                  2022-09-22
# 287930  2022-10-04  2022-10-04   2022-10-05                  2022-09-22
# 287931  2022-10-04  2022-10-04   2022-10-05                  2022-09-22
#
#                                      USER_EMAIL        PRODUCT_ID  \
# 0           martin.llanes@contractors.scale.com  2541086099304823
# 1           martin.llanes@contractors.scale.com  2541086099304823
# 2           martin.llanes@contractors.scale.com  2541086099304823
# 3           martin.llanes@contractors.scale.com  2541086099304823
# 4           martin.llanes@contractors.scale.com  2541086099304823
# ...                                         ...               ...
# 287927  renardalan.luartez@teleworkph-mails.com  8663464900345514
# 287928  renardalan.luartez@teleworkph-mails.com  8663464900345514
# 287929  renardalan.luartez@teleworkph-mails.com  8663464900345514
# 287930  renardalan.luartez@teleworkph-mails.com  8663464900345514
# 287931  renardalan.luartez@teleworkph-mails.com  8663464900345514
#
#                     ATTRIBUTE                     AUDIT_RESULT LEVEL
# 0       additional_image_link  "Fully Correct by the Customer"    QA
# 1       additional_image_link                            false    QA
# 2                       brand  "Fully Correct by the Customer"    QA
# 3                       brand                            false    QA
# 4                       color  "Fully Correct by the Customer"    QA
# ...                       ...                              ...   ...
# 287927                pattern                             true    TW
# 287928                   size  "Fully Correct by the Customer"    TW
# 287929                   size                            false    TW
# 287930                  title  "Fully Correct by the Customer"    TW
# 287931                  title                            false    TW
#
# [287932 rows x 13 columns]

# %%
vcount = len(worklogdf.groupby(['PRODUCT_ID'])['_ID'].nunique())
qacount = worklogdf.groupby(['LEVEL'])['USER_EMAIL'].nunique()
qawork = worklogdf.groupby(['USER_EMAIL'])['PRODUCT_ID'].nunique()
lvlcount = worklogdf.groupby(['AUDIT_LEVEL'])['PRODUCT_ID'].nunique()
qawork = qawork.to_frame()
qacount = qacount.to_frame()
lvlcount = lvlcount.to_frame()
qawork = qawork.sort_values(['PRODUCT_ID'], ascending=False)
print(vcount,qacount)
# Out:
# 15169        USER_EMAIL
# LEVEL
# QA             23
# TW             18

# %%
qawork
# Out:
#                                            PRODUCT_ID
# USER_EMAIL
# jessica.islas@contractors.scale.com              1098
# mariel.espinosa@contractors.scale.com             909
# ricardo.quirino@contractors.scale.com             803
# karyme.morales@contractors.scale.com              773
# antonio.rueda@contractors.scale.com               743
# manuel.garcia@contractors.scale.com               716
# alexa.lazo@contractors.scale.com                  698
# reibill.naco@teleworkph-mails.com                 664
# martin.llanes@contractors.scale.com               622
# josue.moo@contractors.scale.com                   601
# maria.suarez@contractors.scale.com                592
# berwin.santoral@teleworkph-mails.com              499
# jordi.cuevas@contractors.scale.com                496
# july.gongora@contractors.scale.com                484
# salvador.gomez@contractors.scale.com              472
# johnpaul.sison@teleworkph-mails.com               466
# alejandra.romero@contractors.scale.com            449
# melisa.garcia@contractors.scale.com               449
# renardalan.luartez@teleworkph-mails.com           441
# ericajoyce.deguzman@teleworkph-mails.com          432
# mervin.delacruz@teleworkph-mails.com              424
# juan.herrera@contractors.scale.com                400
# marrion.bermudez@teleworkph-mails.com             395
# jaimee.llamera@teleworkph-mails.com               379
# monserrat.maya@contractors.scale.com              364
# jonel.magana@teleworkph-mails.com                 361
# rodrigo.muniz@contractors.scale.com               347
# jose.gonzalez@contractors.scale.com               340
# markchristian.galvez@teleworkph-mails.com         332
# gabriel.villabeytia@contractors.scale.com         330
# fernanda.gallegos@contractors.scale.com           312
# christoper.laurente@teleworkph-mails.com          304
# alyssa.agsao@teleworkph-mails.com                 302
# arnelito.basinillo@teleworkph-mails.com           299
# glenda.roxas@teleworkph-mails.com                 283
# edel.sabater@contractors.scale.com                267
# bryanpaul.polintan@teleworkph-mails.com           259
# mark.batinga@teleworkph-mails.com                 218
# maryrose.bigcas@teleworkph-mails.com              217
# paola.venturina@teleworkph-mails.com              189
# ada.canul@contractors.scale.com                   147

# %%
#Send Update as Slack Message 
rdate = datetime.now()
now = datetime.now()
day = now.strftime("%m-%d-%Y")


if __name__ == '__main__':
     url = "https://hooks.slack.com/services/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"
     message1 = ("Throughput Update \n"+"Number of variants audited - "+str(vcount)+"\n"+"Total number of QA/TW active -"+str(qacount))
     message2 = lvlcount.to_json()
     message3 = qawork.to_json()
     title = (f"Customer Feedback Ingestion " + day+" :credo_icon_results_speak_loudest:")

     slack_data = {
         "username": "Ops Reporting Bot",
         "icon_emoji":":credo_icon_results_speak_loudest:",
         #"channel" : "#flamingo-ops-daily-updates",
          "attachments": [
             {
                 "color": "#FFFFFF",
                 "blocks": [
                 {
                     "type": "header",
                     "text": {
                         "type": "plain_text",
                         "text": title,
                         }
                     },

                 {
                         "type": "section",
                         "text": {
                             "type": "plain_text",
                             "text": message1
                         }
                     },
                 {
                         "type": "divider"
                     },
                        {
                         "type": "section",
                         "text": {
                             "type": "plain_text",
                             "text": message2
                         }
                     },

                     {
                         "type": "section",
                         "text": {
                             "type": "plain_text",
                             "text": message3
                         }
                     }
                     ]
             }
         ]

     }


     byte_length = str(sys.getsizeof(slack_data))
     headers = {'Content-Type': "application/json", 'Content-Length': byte_length}
     response = requests.post(url, data=json.dumps(slack_data), headers=headers)
     if response.status_code != 200:
         raise Exception(response.status_code, response.text)
