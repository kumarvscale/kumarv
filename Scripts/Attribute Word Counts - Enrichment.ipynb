# %%
import pandas as pd
import numpy as np
import snowflake.connector
from collections import defaultdict
import json
import re
import requests
import sys
import random
import requests
import tabulate
from datetime import datetime
import schedule
import time

# %%
filename = "att.txt"

# Open the file in read mode
with open(filename, "r") as file:

    # Read the contents of the file into a string
    text = file.read()

    # Split the text into individual words
    words = text.split()

    # Create an empty dictionary to store the word counts
    word_counts = {}

    # Loop over each word in the list of words
    for word in words:

        # If the word is not already in the dictionary, add it with a count of 1
        if word not in word_counts:
            word_counts[word] = 1

        # If the word is already in the dictionary, increment its count by 1
        else:
            word_counts[word] += 1

# Print the word counts
for word, count in word_counts.items():
    print(word, count)
# Out:
# color_normalized 1413
# , 17689
# material 1576
# gender 636
# product_type 1186
# shirt_fit 38
# model_info 160
# neckline 37
# sub_brand 1330
# origin_location 949
# dimensions 1227
# sleeve_length_style 49
# fit_type 292
# product_length 740
# collar_style 43
# sleeve_length 119
# t_shirt_style 19
# pattern 440
# style 483
# sleeve_style 40
# hem_style 37
# closure_style 38
# condition 830
# instructions 618
# age_group 463
# occasion 287
# product_weight 724
# product_height 640
# recommended_use 655
# sub_title 102
# product_width 724
# top_length_style 8
# cuff_style 31
# waist_rise 79
# inseam 72
# coat_jacket_fit 23
# activewear_top_style 13
# activity 74
# product_volume 301
# holiday 24
# casual_shirt_style 8
# dress_length_style 4
# dress_style 5
# skirt_length 16
# waist_style 8
# free_shipping 52
# returns 47
# pant_fit 26
# pant_closure_style 85
# jeans_style 18
# jean_wash 20
# pant_leg_style 41
# fabric_type 67
# pant_length_style 20
# pant_style 27
# fb_pixel_content_id 34
# finish 275
# gemstone 85
# gemstone_cut 26
# gemstone_clarity 18
# metal_stamp/purity 27
# ring_style 16
# plating_material 35
# ring_size 9
# is_handmade 25
# gemstone_creation_method 20
# bracelet_style 11
# health_concern 160
# earring_style 11
# chain_length 19
# heel_height 29
# shoe_closure 20
# toe_style 22
# boot_shaft_height 7
# heel_height_style 19
# boot_style 9
# shoe_style 20
# is_water_resistant 27
# shoe_width 20
# "women 5
# s_shoe_width", 5
# calf_width 2
# sweater_style 20
# pant_front_type 5
# sweatshirt_style 11
# bra_style 10
# underwear_style 19
# support_level 9
# shapewear_style 14
# swimwear_strap_style 6
# decor_style 95
# neck_size 8
# swimwear_type 15
# swimwear_top_style 6
# swimwear_style 8
# swimwear_bottom_style 6
# has_custom_parsed_description 50
# is_orthopedic 4
# country 33
# necklace_style 10
# charm_pendant_style 10
# theme 13
# jacket_length_style 5
# coat_jacket_style 14
# warmth 8
# artwork_subject 9
# shape 36
# frame_size 4
# is_antique 7
# indoor/outdoor_use 39
# is_solid_wood 16
# artificial_plant_flower_type 2
# mirror_size 2
# sneaker_product_line 7
# watch_band_material 11
# capacity 194
# shorts_length_style 14
# language 28
# ingredients 143
# skirt_style 5
# skirt_length_style 4
# shorts_style 14
# shapewear_concern 4
# watch_case_shape 3
# watch_case_diameter 4
# watch_type 4
# watch_band_length 9
# watch_band_diameter 4
# watch_style 7
# watch_display_type 3
# watch_band_style 3
# watch_band_width 4
# model 15
# screen_size 9
# battery_life 6
# cell_phone_service_provider 2
# cellular_band 3
# cellular_generation 1
# number_of_sim_card_slots 2
# connector_type 10
# display_technology 2
# storage_capacity 11
# carpet_tile_installation_method 2
# pillow_type 2
# sleepwear_style 14
# scent 65
# wallet_style 7
# skin_type 58
# fixture_design 7
# thread_count 16
# pieces_included 13
# fill_material 9
# hair_color_shade 4
# hair_type 20
# form 33
# clock_placement 1
# number_of_pieces 7
# suit_style 2
# hair_jewelry_type 2
# light_bulb_type 13
# light_bulb_wattage 12
# mirror_type 2
# has_lights 6
# light_bulb_base_type 7
# lamp_height 4
# power_source 7
# pillow_shape 1
# effect 36
# lip_gloss_effect 6
# coverage 10
# christmas_light_type 2
# time_display 3
# seat_back_style 6
# is_upholstered 7
# is_assembly_required 25
# arm_style 4
# seat_height 7
# seating_capacity 5
# number_of_seats 7
# comfort_level 6
# is_adjustable 4
# mattress_top 2
# number_in_set 7
# seat_back_height 2
# table_height 10
# mascara_effect 9
# product_form 30
# body_part 21
# care_instructions 5
# shapewear_control_level 4
# diffuser_fragrance_oil_type 2
# air_freshener_usage 2
# result_time 7
# skin_tone 1
# eyewear_rim 4
# lens_material 4
# lens_type 3
# uv_rating 3
# vase_type 2
# sofa_type 3
# bed_type 6
# living_room_chair_type 1
# sofa_sectional_configuration 1
# skin_care_concern 15
# stop_use_indications 9
# concern 13
# target_area 13
# spf_value 4
# protection 8
# mattress_foundation_profile 3
# ottoman_type 1
# towel_type 2
# nutrient_name 1
# dosage 3
# nutrient_amount 1
# serving_size 1
# flavor 3
# absorbency 2
# package_quantity 15
# educational_focus 1
# scale_display_indicator 1
# fan_diameter 1
# end_table_type 2
# desk_type 3
# number_of_shelves 5
# mirror_mount_type 1
# mirror_shape 1
# dining_chair_type 2
# number_of_drawers 8
# storage_type 3
# office_chair_type 2
# christmas_tree_height 2
# operating_system 3
# ram_memory 2
# resolution 7
# graphics_card_model 1
# hard_drive_type 3
# optical_drive 1
# processor_speed 2
# processor_type 2
# usb_type 6
# front_facing_camera_megapixel 2
# video_resolution 2
# wireless_technologies 4
# organization_included 1
# computer_case_form_factor 1
# core_construction 1
# string_light_type 2
# inflatable_mattress_type 1
# bed_waterbed_accessory_type 2
# is_pump_included 1
# mattress_foundation_type 2
# wattage 2
# is_powered 2
# max_screen_size 2
# entertainment_unit_type 1
# dresser_type 1
# dining_table_type 2
# power_type 3
# christmas_tree_type 1
# christmas_tree_light_type 2
# rear_facing_camera_megapixels 1
# bluetooth_technology 5
# sim_type_supported 1
# stand_by_time 2
# food_processor_functions 2
# mixer_blender_type 1
# number_of_blades_included 2
# type 2
# inactive_ingredients 3
# audio_power_output 1
# bookcase_type 1
# shelf_life 1
# vacuum_type 2
# clock_mechanism 1
# coffee_maker_type 1
# keywords 1
# vesa_mounting_standard 1
# cooker_capacity 2
# slice_capacity 1
# cooker_steamer_type 1
# bag_type 3
# lens_tint 1
# warnings 2
# air_freshener_form 1
# software_system_requirements 1
# required_peripherals 1
# software_version 1
# talk_time 1
# focal_length 1
# zoom_specs 1
# batteries_required 1
# clock_style 1
# motherboard_form_factor 1
# release_date 1
# video_game_series 1
# video_game_platform 1
