# %%
import time

# %%
f1 = '"'
r1 = "'"
f2 = "[{'key':"
r2 = "{"
f3 = ",'value':"
r3 = ": "
f4 = "'.'"
r4 = "'. '"
f5 = "]},{'key':"
r5 = "], "
f6 = "]}]"
r6 = "]}"
f7 = "women's"
r7 = "womens"
f8 = "men's"
r8 = "mens"

#1st Replace
with open(r'scale_ai_parity_assessment_data_2022-08-17 2.csv', 'r') as file:
    data = file.read()
    data = data.replace(f1, r1)
with open(r'scale_ai_parity_assessment_data_2022-08-17 2.csv', 'w') as file:
    file.write(data)
print("Replacing first string")
time.sleep(4)

#2nd Replace
with open(r'scale_ai_parity_assessment_data_2022-08-17 2.csv', 'r') as file:
    data = file.read()
    data = data.replace(f2, r2)
with open(r'scale_ai_parity_assessment_data_2022-08-17 2.csv', 'w') as file:
    file.write(data)
print("Replacing second string")
time.sleep(4)
    
    
#3rd Replace
with open(r'scale_ai_parity_assessment_data_2022-08-17 2.csv', 'r') as file:
    data = file.read()
    data = data.replace(f3, r3)
with open(r'scale_ai_parity_assessment_data_2022-08-17 2.csv', 'w') as file:
    file.write(data)
print("Replacing third string")
time.sleep(4)

#4th Replace
with open(r'scale_ai_parity_assessment_data_2022-08-17 2.csv', 'r') as file:
    data = file.read()
    data = data.replace(f4, r4)
with open(r'scale_ai_parity_assessment_data_2022-08-17 2.csv', 'w') as file:
    file.write(data)
print("Replacing fourth string")
time.sleep(4)

#5th Replace
with open(r'scale_ai_parity_assessment_data_2022-08-17 2.csv', 'r') as file:
    data = file.read()
    data = data.replace(f5, r5)
with open(r'scale_ai_parity_assessment_data_2022-08-17 2.csv', 'w') as file:
    file.write(data)
print("Replacing fifth string")
time.sleep(4)
    
#6th Replace
with open(r'scale_ai_parity_assessment_data_2022-08-17 2.csv', 'r') as file:
    data = file.read()
    data = data.replace(f6, r6)
with open(r'scale_ai_parity_assessment_data_2022-08-17 2.csv', 'w') as file:
    file.write(data)
print("Replacing sixth string")
time.sleep(4)

#7th Replace
with open(r'scale_ai_parity_assessment_data_2022-08-17 2.csv', 'r') as file:
    data = file.read()
    data = data.replace(f7, r7)
with open(r'scale_ai_parity_assessment_data_2022-08-17 2.csv', 'w') as file:
    file.write(data)
print("Replacing seventh string")
time.sleep(4)

#8th Replace
with open(r'scale_ai_parity_assessment_data_2022-08-17 2.csv', 'r') as file:
    data = file.read()
    data = data.replace(f8, r8)
with open(r'scale_ai_parity_assessment_data_2022-08-17 2.csv', 'w') as file:
    file.write(data)
print("Replacing 8th string")
time.sleep(4)
    
    
print("Format corrections made. File saved")
# Out:
# Replacing first string
# Replacing second string
# Replacing third string
# Replacing fourth string
# Replacing fifth string
# Replacing sixth string
# Replacing seventh string
# Replacing 8th string
# Format corrections made. File saved
